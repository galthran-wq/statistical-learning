# %%
import numpy as np
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
import seaborn as sns
import scipy as sp
import faraway.utils

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (20, 10)

# %%
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(42)

X_train = np.random.normal(size=100)
X_val = np.random.normal(size=100)
pol = PolynomialFeatures(3).fit_transform(X_train.reshape(1, -1))

# y_train = PolynomialFeatures(3).fit_transform(X_train.reshape(1, -1)) + np.random.normal(size=100)
# y_val = PolynomialFeatures(3).fit_transform(X_test)+  np.random.normal(size=100)

# %%
plt.scatter(X_train, y_train)
